# %% [markdown]
# <h1 style="color: red; text-align: center; font-family: Arial, sans-serif; font-size: 32px;">
#   Creation of Data frame
# </h1>

# %%
#import pandas library
import pandas as pd

# %%
#creating data frame 
df=pd.DataFrame([[10,14,23,32],[23,13,21,34],[23,31,24,17]],
columns=["CD","DBMS","CAO","DSS"])

# %%
df
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    14   23   32
# 1  23    13   21   34
# 2  23    31   24   17

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns=["CD","CAO","DBMS","DSS"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    14   23   32
# 1  23    13   21   34
# 2  23    31   24   17
# 3   5     7    6    8

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    CD  DBMS  CAO  DSS  DM
# 0  10    14   23   32  12
# 1  23    13   21   34  15
# 2  23    31   24   17  16
# 3   5     7    6    8  14

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  CAO  DSS  DM
# 0  10    14   23   32  12
# 2  23    31   24   17  16
# 3   5     7    6    8  14

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    14   23   32
# 1  23    13   21   34
# 2  23    31   24   17
# 3   5     7    6    8

# %%
#Finding mean of Dss
print("Mean of Dss",df5["DSS"].mean())
# Out:
# Mean of Dss 22.75

# %%
#Finding mode of Dss
print("Mode of Dss",df5["DSS"].mode())
# Out:
# Mode of Dss 0     8
# 1    17
# 2    32
# 3    34
# Name: DSS, dtype: int64

# %%
#Finding median of Dss
print("Median of Dss",df5["DSS"].median())
# Out:
# Median of Dss 24.5

# %%
#Finding min of Dss
print("Min of Dss",df5["DSS"].min())
# Out:
# Min of Dss 8

# %%
#Finding max of Dss
print("Max of Dss",df5["DSS"].max())
# Out:
# Max of Dss 34

# %%
#Create a Student name list
Name=["Kartik","Harshal","Ram","Shrihari"]
Name
# Out:
# ['Kartik', 'Harshal', 'Ram', 'Shrihari']

# %%
#Creating a series 
Roll_listed=pd.Series(Name,index=[1,2,3,4])

# %%
print(Roll_listed)
# Out:
# 1      Kartik
# 2     Harshal
# 3         Ram
# 4    Shrihari
# dtype: object
